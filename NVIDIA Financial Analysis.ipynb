# %%
import yfinance as yf
ticker_symbol='NVDA'
financials= yf.Ticker(ticker_symbol).cashflow
financials
# Out:
#                                                   2025-01-31    2024-01-31  \
# Free Cash Flow                                  6.085300e+10  2.702100e+10
# Repurchase Of Capital Stock                    -3.370600e+10 -9.533000e+09
# Repayment Of Debt                              -1.250000e+09 -1.250000e+09
# Issuance Of Debt                                         NaN  0.000000e+00
# Capital Expenditure                            -3.236000e+09 -1.069000e+09
# Interest Paid Supplemental Data                 2.460000e+08  2.520000e+08
# Income Tax Paid Supplemental Data               1.511800e+10  6.549000e+09
# End Cash Position                               8.589000e+09  7.280000e+09
# Beginning Cash Position                         7.280000e+09  3.389000e+09
# Changes In Cash                                 1.309000e+09  3.891000e+09
# Financing Cash Flow                            -4.235900e+10 -1.363300e+10
# ...

# %%
financials.to_csv(r'Financials.xlsx', index=False, encoding='utf-8-sig')

# %%
financials_transposed = financials.transpose()
financials_transposed_scaled = financials_transposed / 1_000_000_000
title = "Scaled Cash Flow Statement (in billions)"
financials_transposed_scaled.columns.name = title
financials_transposed_scaled
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  \
# 2025-01-31                                        60.853
# 2024-01-31                                        27.021
# 2023-01-31                                         3.808
# 2022-01-31                                         8.132
# 2021-01-31                                           NaN
#
# Scaled Cash Flow Statement (in billions)  Repurchase Of Capital Stock  \
# 2025-01-31                                                    -33.706
# 2024-01-31                                                     -9.533
# 2023-01-31                                                    -10.039
# 2022-01-31                                                      0.000
# 2021-01-31                                                        NaN
#
# Scaled Cash Flow Statement (in billions)  Repayment Of Debt  Issuance Of Debt  \
# 2025-01-31                                            -1.25               NaN
# ...

# %%
df=financials_transposed_scaled
df.head()
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  \
# 2025-01-31                                        60.853
# 2024-01-31                                        27.021
# 2023-01-31                                         3.808
# 2022-01-31                                         8.132
# 2021-01-31                                           NaN
#
# Scaled Cash Flow Statement (in billions)  Repurchase Of Capital Stock  \
# 2025-01-31                                                    -33.706
# 2024-01-31                                                     -9.533
# 2023-01-31                                                    -10.039
# 2022-01-31                                                      0.000
# 2021-01-31                                                        NaN
#
# Scaled Cash Flow Statement (in billions)  Repayment Of Debt  Issuance Of Debt  \
# 2025-01-31                                            -1.25               NaN
# ...

# %%
import pandas as pd
df=df.iloc[:-1]
df_without_NaN= df.fillna(0).copy()
market_cap_NVDA= [4277, 3355, 1223, 364.18]
df_without_NaN['Market Cap']=market_cap_NVDA
df_without_NaN
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  \
# 2025-01-31                                        60.853
# 2024-01-31                                        27.021
# 2023-01-31                                         3.808
# 2022-01-31                                         8.132
#
# Scaled Cash Flow Statement (in billions)  Repurchase Of Capital Stock  \
# 2025-01-31                                                    -33.706
# 2024-01-31                                                     -9.533
# 2023-01-31                                                    -10.039
# 2022-01-31                                                      0.000
#
# Scaled Cash Flow Statement (in billions)  Repayment Of Debt  Issuance Of Debt  \
# 2025-01-31                                            -1.25             0.000
# 2024-01-31                                            -1.25             0.000
# 2023-01-31                                             0.00             0.000
# ...

# %%
print(df_without_NaN.columns)
# Out:
# Index(['Free Cash Flow', 'Repurchase Of Capital Stock', 'Repayment Of Debt',
#        'Issuance Of Debt', 'Capital Expenditure',
#        'Interest Paid Supplemental Data', 'Income Tax Paid Supplemental Data',
#        'End Cash Position', 'Beginning Cash Position', 'Changes In Cash',
#        'Financing Cash Flow', 'Cash Flow From Continuing Financing Activities',
#        'Net Other Financing Charges', 'Proceeds From Stock Option Exercised',
#        'Cash Dividends Paid', 'Common Stock Dividend Paid',
#        'Net Common Stock Issuance', 'Common Stock Payments',
#        'Net Issuance Payments Of Debt', 'Net Long Term Debt Issuance',
#        'Long Term Debt Payments', 'Long Term Debt Issuance',
#        'Investing Cash Flow', 'Cash Flow From Continuing Investing Activities',
#        'Net Other Investing Changes', 'Net Investment Purchase And Sale',
#        'Sale Of Investment', 'Purchase Of Investment',
#        'Net Business Purchase And Sale', 'Purchase Of Business',
# ...

# %%
df_without_NaN=df_without_NaN.copy()
df_without_NaN['EBITDA'] = df_without_NaN['Operating Cash Flow'] + df_without_NaN['Depreciation And Amortization']
df_without_NaN
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  \
# 2025-01-31                                        60.853
# 2024-01-31                                        27.021
# 2023-01-31                                         3.808
# 2022-01-31                                         8.132
#
# Scaled Cash Flow Statement (in billions)  Repurchase Of Capital Stock  \
# 2025-01-31                                                    -33.706
# 2024-01-31                                                     -9.533
# 2023-01-31                                                    -10.039
# 2022-01-31                                                      0.000
#
# Scaled Cash Flow Statement (in billions)  Repayment Of Debt  Issuance Of Debt  \
# 2025-01-31                                            -1.25             0.000
# 2024-01-31                                            -1.25             0.000
# 2023-01-31                                             0.00             0.000
# ...

# %%
import matplotlib.pyplot as plt
cols_for_analysis= ['Operating Cash Flow', 'Capital Expenditure', 'Net Common Stock Issuance', 'Net Issuance Payments Of Debt', 'EBITDA']
NVIDIA_TA=df_without_NaN[cols_for_analysis].plot(kind='line', figsize=(10,6))
plt.title('Trend Analysis NVIDIA (in billions)')
plt.xlabel('Year')
plt.ylabel('Cash Flow (billions)')
plt.legend()
plt.grid(True)

# %%
competitor1_ticker_symbol= 'AMD'
AMDfinancials=yf.Ticker(competitor1_ticker_symbol).cashflow
AMDfinancials_transposed = AMDfinancials.transpose()
AMDfinancials_transposed_scaled = AMDfinancials_transposed / 1_000_000_000
AMDtitle = "Scaled Cash Flow Statement (in billions)"
AMDfinancials_transposed_scaled.columns.name = AMDtitle
dfAMD=AMDfinancials_transposed_scaled
dfAMD_without_NaN= dfAMD.dropna(axis=1)
dfAMD_without_NaN.columns
# Out:
# Index([], dtype='object', name='Scaled Cash Flow Statement (in billions)')

# %%
dfAMD_without_NaN=dfAMD.copy()
dfAMD_without_NaN=dfAMD_without_NaN.iloc[:-1]
dfAMD_without_NaN['EBITDA'] = dfAMD_without_NaN['Operating Cash Flow'] + dfAMD_without_NaN['Depreciation And Amortization']
market_cap_AMD= [110.42, 173.77, 104.43, 238.14]
dfAMD_without_NaN['Market Cap']=market_cap_AMD
dfAMD_without_NaN
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  \
# 2024-12-31                                         2.405
# 2023-12-31                                         1.121
# 2022-12-31                                         3.115
# 2021-12-31                                         3.220
#
# Scaled Cash Flow Statement (in billions)  Repurchase Of Capital Stock  \
# 2024-12-31                                                     -1.590
# 2023-12-31                                                     -1.412
# 2022-12-31                                                     -4.108
# 2021-12-31                                                     -1.999
#
# Scaled Cash Flow Statement (in billions)  Repayment Of Debt  Issuance Of Debt  \
# 2024-12-31                                           -0.750             0.000
# 2023-12-31                                            0.000             0.000
# 2022-12-31                                           -0.312             0.991
# ...

# %%
AMD_TA=dfAMD_without_NaN[cols_for_analysis].plot(kind='line', figsize=(10,6))
plt.title('Trend Analysis AMD (in billions)')
plt.xlabel('Year')
plt.ylabel('Cash Flow (billions)')
plt.legend()
plt.grid(True)

# %%
competitor2_ticker_symbol= 'INTC'
Intelfinancials=yf.Ticker(competitor2_ticker_symbol).cashflow
Intelfinancials_transposed = Intelfinancials.transpose()
Intelfinancials_transposed_scaled = Intelfinancials_transposed / 1_000_000_000
Inteltitle = "Scaled Cash Flow Statement (in billions)"
Intelfinancials_transposed_scaled.columns.name = Inteltitle
dfIntel=Intelfinancials_transposed_scaled
dfIntel_without_NaN= dfIntel.dropna(axis=1)
dfIntel_without_NaN.columns
# Out:
# Index([], dtype='object', name='Scaled Cash Flow Statement (in billions)')

# %%
dfIntel_without_NaN=dfIntel.copy()
dfIntel_without_NaN=dfIntel_without_NaN.iloc[:-1]
dfIntel_without_NaN['EBITDA'] = dfIntel_without_NaN['Operating Cash Flow'] + dfIntel_without_NaN['Depreciation And Amortization']
market_cap_Intel= [204.16, 209.6, 109.07, 211.85]
dfIntel_without_NaN['Market Cap']=market_cap_Intel
dfIntel_without_NaN
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  \
# 2024-12-31                                       -15.656
# 2023-12-31                                       -14.279
# 2022-12-31                                        -9.411
# 2021-12-31                                         9.127
#
# Scaled Cash Flow Statement (in billions)  Repurchase Of Capital Stock  \
# 2024-12-31                                                        NaN
# 2023-12-31                                                      0.000
# 2022-12-31                                                      0.000
# 2021-12-31                                                     -2.415
#
# Scaled Cash Flow Statement (in billions)  Repayment Of Debt  Issuance Of Debt  \
# 2024-12-31                                           -9.637            10.324
# 2023-12-31                                           -4.367            11.391
# 2022-12-31                                           -4.984            10.493
# ...

# %%
IntelTA=dfIntel_without_NaN[cols_for_analysis].plot(kind='line', figsize=(10,6))
plt.title('Trend Analysis Intel (in billions)')
plt.xlabel('Year')
plt.ylabel('Cash Flow (billions)')
plt.legend()
plt.grid(True)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the x-axis positions for each label
x = np.arange(len(cols_for_analysis))

# Define the width of each bar
bar_width = 0.25

# Plotting the bars for each company for financial metrics
plt.figure(figsize=(12, 8))

# NVIDIA bars for financial metrics
plt.bar(x - bar_width, df_without_NaN[cols_for_analysis].mean(), width=bar_width, label='NVIDIA')

# AMD bars for financial metrics
plt.bar(x, dfAMD_without_NaN[cols_for_analysis].mean(), width=bar_width, label='AMD')

# Intel bars for financial metrics
plt.bar(x + bar_width, dfIntel_without_NaN[cols_for_analysis].mean(), width=bar_width, label='Intel')

# Setting labels and title for financial metrics plot
plt.xlabel('Metrics')
plt.ylabel('Mean Values (in billions)')
plt.title('Comparison of Mean Financial Metrics Across Companies (2020-2023/2024)')
plt.xticks(x, cols_for_analysis, rotation=45)
plt.legend()

plt.show()

# Plotting market capitalization for each company
plt.figure(figsize=(8, 6))

plt.bar(['NVIDIA', 'AMD', 'Intel'], 
        [df_without_NaN['Market Cap'].mean(), 
         dfAMD_without_NaN['Market Cap'].mean(), 
         dfIntel_without_NaN['Market Cap'].mean()], 
        color=['blue', 'green', 'orange'])

# Setting labels and title for market capitalization plot
plt.xlabel('Company')
plt.ylabel('Mean Market Capitalization')
plt.title('Comparison of Mean Market Capitalization Across Companies (2020-2023/2024)')

plt.show()

# %%
RND_Investments_NVDA= [3.92,5.27, 7.34, 8.68]
df_without_NaN['R&D Investments']=RND_Investments_NVDA
RND_Investments_AMD= [1.98, 2.85, 5.01, 5.87]
dfAMD_without_NaN['R&D Investments']=RND_Investments_AMD
RND_Investments_Intel= [13.56, 15.19, 17.53, 16.05]
dfIntel_without_NaN['R&D Investments']=RND_Investments_Intel
df_without_NaN
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  \
# 2025-01-31                                        60.853
# 2024-01-31                                        27.021
# 2023-01-31                                         3.808
# 2022-01-31                                         8.132
#
# Scaled Cash Flow Statement (in billions)  Repurchase Of Capital Stock  \
# 2025-01-31                                                    -33.706
# 2024-01-31                                                     -9.533
# 2023-01-31                                                    -10.039
# 2022-01-31                                                      0.000
#
# Scaled Cash Flow Statement (in billions)  Repayment Of Debt  Issuance Of Debt  \
# 2025-01-31                                            -1.25             0.000
# 2024-01-31                                            -1.25             0.000
# 2023-01-31                                             0.00             0.000
# ...

# %%
dfAMD_without_NaN = dfAMD_without_NaN.dropna(axis=1)
dfAMD_without_NaN
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  \
# 2024-12-31                                         2.405
# 2023-12-31                                         1.121
# 2022-12-31                                         3.115
# 2021-12-31                                         3.220
#
# Scaled Cash Flow Statement (in billions)  Repurchase Of Capital Stock  \
# 2024-12-31                                                     -1.590
# 2023-12-31                                                     -1.412
# 2022-12-31                                                     -4.108
# 2021-12-31                                                     -1.999
#
# Scaled Cash Flow Statement (in billions)  Repayment Of Debt  Issuance Of Debt  \
# 2024-12-31                                           -0.750             0.000
# 2023-12-31                                            0.000             0.000
# 2022-12-31                                           -0.312             0.991
# ...

# %%
dfIntel_without_NaN = dfIntel_without_NaN.dropna(axis=1)
dfIntel_without_NaN
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  Repayment Of Debt  \
# 2024-12-31                                       -15.656             -9.637
# 2023-12-31                                       -14.279             -4.367
# 2022-12-31                                        -9.411             -4.984
# 2021-12-31                                         9.127             -2.500
#
# Scaled Cash Flow Statement (in billions)  Issuance Of Debt  \
# 2024-12-31                                          10.324
# 2023-12-31                                          11.391
# 2022-12-31                                          10.493
# 2021-12-31                                           4.974
#
# Scaled Cash Flow Statement (in billions)  Issuance Of Capital Stock  \
# 2024-12-31                                                   12.714
# 2023-12-31                                                    1.511
# 2022-12-31                                                    1.032
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_without_NaN, x='Market Cap', y='R&D Investments')
plt.title('R&D Investments vs. Market Cap')
plt.xlabel('Market Cap')
plt.ylabel('R&D Investments')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.lineplot(data=dfAMD_without_NaN, x='Market Cap', y='R&D Investments')
plt.title('R&D Investments vs. Market Cap')
plt.xlabel('Market Cap')
plt.ylabel('R&D Investments')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 6))
sns.lineplot(data=dfIntel_without_NaN, x='Market Cap', y='R&D Investments')
plt.title('R&D Investments vs. Market Cap')
plt.xlabel('Market Cap')
plt.ylabel('R&D Investments')
plt.show()

# %%
dfAMD_without_NaN
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  \
# 2024-12-31                                         2.405
# 2023-12-31                                         1.121
# 2022-12-31                                         3.115
# 2021-12-31                                         3.220
#
# Scaled Cash Flow Statement (in billions)  Repurchase Of Capital Stock  \
# 2024-12-31                                                     -1.590
# 2023-12-31                                                     -1.412
# 2022-12-31                                                     -4.108
# 2021-12-31                                                     -1.999
#
# Scaled Cash Flow Statement (in billions)  Repayment Of Debt  Issuance Of Debt  \
# 2024-12-31                                           -0.750             0.000
# 2023-12-31                                            0.000             0.000
# 2022-12-31                                           -0.312             0.991
# ...

# %%
from sklearn.linear_model import LinearRegression

try:

    dfAMD_without_NaN = dfAMD_without_NaN.copy()
    dfIntel_without_NaN = dfIntel_without_NaN.copy()
    dfAMD_without_NaN['Year'] = [2020, 2021, 2022, 2023]
    dfIntel_without_NaN['Year'] = [2020, 2021, 2022, 2023]

    X_columns = ['Year']

    models_and_predictions_AMD = {}
    models_and_predictions_Intel = {}

    for column in cols_for_analysis:
        X_AMD = dfAMD_without_NaN[X_columns]  
        y_AMD = dfAMD_without_NaN[column] 

        X_Intel = dfIntel_without_NaN[X_columns]  
        y_Intel = dfIntel_without_NaN[column] 

        model_AMD = LinearRegression()
        model_AMD.fit(X_AMD, y_AMD)

        model_Intel = LinearRegression()
        model_Intel.fit(X_Intel, y_Intel)

        predicted_values_2024_AMD = model_AMD.predict(pd.DataFrame([[2024]], columns=X_columns))
        predicted_values_2024_Intel = model_Intel.predict(pd.DataFrame([[2024]], columns=X_columns))

        models_and_predictions_AMD[column] = {'model': model_AMD, 'predicted_values_2024': predicted_values_2024_AMD}
        models_and_predictions_Intel[column] = {'model': model_Intel, 'predicted_values_2024': predicted_values_2024_Intel}

    for column, data in models_and_predictions_AMD.items():
        print(f"Predicted {column} for AMD in 2024:", data['predicted_values_2024'])

    for column, data in models_and_predictions_Intel.items():
        print(f"Predicted {column} for Intel in 2024:", data['predicted_values_2024'])

except Exception as e:
    print("An error occurred:", e)
# Out:
# Predicted Operating Cash Flow for AMD in 2024: [3.783]
# Predicted Capital Expenditure for AMD in 2024: [-0.208]
# Predicted Net Common Stock Issuance for AMD in 2024: [-3.258]
# Predicted Net Issuance Payments Of Debt for AMD in 2024: [0.7145]
# Predicted EBITDA for AMD in 2024: [4.7885]
# Predicted Operating Cash Flow for Intel in 2024: [33.0285]
# Predicted Capital Expenditure for Intel in 2024: [-20.779]
# Predicted Net Common Stock Issuance for Intel in 2024: [-8.256]
# Predicted Net Issuance Payments Of Debt for Intel in 2024: [4.885]
# Predicted EBITDA for Intel in 2024: [45.6485]

# %%
import pandas as pd

# Adjust display settings to show all rows and columns
pd.set_option('display.max_rows', 5)
pd.set_option('display.max_columns', 55)

# Display the DataFrame
dfAMD_without_NaN_3 = dfAMD_without_NaN.copy()
dfAMD_without_NaN_3
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  \
# 2024-12-31                                         2.405
# 2023-12-31                                         1.121
# 2022-12-31                                         3.115
# 2021-12-31                                         3.220
#
# Scaled Cash Flow Statement (in billions)  Repurchase Of Capital Stock  \
# 2024-12-31                                                     -1.590
# 2023-12-31                                                     -1.412
# 2022-12-31                                                     -4.108
# 2021-12-31                                                     -1.999
#
# Scaled Cash Flow Statement (in billions)  Repayment Of Debt  Issuance Of Debt  \
# 2024-12-31                                           -0.750             0.000
# 2023-12-31                                            0.000             0.000
# 2022-12-31                                           -0.312             0.991
# ...

# %%
dfAMD_without_NaN_3 = dfAMD_without_NaN_3.fillna(0)

# Define replacement values
replacement_value_1 = (-0.17150000000000887, -0.1715)
replacement_value_2 = (-0.3714999999999691, -0.3715)
replacement_value_3 = (1.9979999999999905, 1.998)
replacement_value_4 = (0.8079999999999927, 0.808)
replacement_value_5 = (0,0)

# Replace values in specific columns
dfAMD_without_NaN_3['Capital Expenditure'] = dfAMD_without_NaN_3['Capital Expenditure'].replace(*replacement_value_1)
dfAMD_without_NaN_3['Net Common Stock Issuance'] = dfAMD_without_NaN_3['Net Common Stock Issuance'].replace(*replacement_value_2)
dfAMD_without_NaN_3['Operating Cash Flow'] = dfAMD_without_NaN_3['Operating Cash Flow'].replace(*replacement_value_3)
dfAMD_without_NaN_3['EBITDA'] = dfAMD_without_NaN_3['EBITDA'].replace(*replacement_value_4)
dfAMD_without_NaN_3['Net Issuance Payments Of Debt']=dfAMD_without_NaN_3['Net Issuance Payments Of Debt'].replace(*replacement_value_5)
dfAMD_without_NaN_3
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  \
# 2024-12-31                                         2.405
# 2023-12-31                                         1.121
# 2022-12-31                                         3.115
# 2021-12-31                                         3.220
#
# Scaled Cash Flow Statement (in billions)  Repurchase Of Capital Stock  \
# 2024-12-31                                                     -1.590
# 2023-12-31                                                     -1.412
# 2022-12-31                                                     -4.108
# 2021-12-31                                                     -1.999
#
# Scaled Cash Flow Statement (in billions)  Repayment Of Debt  Issuance Of Debt  \
# 2024-12-31                                           -0.750             0.000
# 2023-12-31                                            0.000             0.000
# 2022-12-31                                           -0.312             0.991
# ...

# %%
dfAMD_without_NaN_3[cols_for_analysis].dtypes
# Out:
# Scaled Cash Flow Statement (in billions)
# Operating Cash Flow              float64
# Capital Expenditure              float64
# Net Common Stock Issuance        float64
# Net Issuance Payments Of Debt    float64
# EBITDA                           float64
# dtype: object

# %%
dfAMD_without_NaN_3[cols_for_analysis].plot(kind='line', figsize=(10,6))
plt.title('Trend Analysis AMD (in billions)')
plt.xlabel('Year')
plt.ylabel('Cash Flow (billions)')
plt.legend()
plt.grid(True)

# %%
dfIntel_without_NaN_4 = dfIntel_without_NaN.copy()
dfIntel_without_NaN_4 = dfIntel_without_NaN_4.fillna(0)
dfIntel_without_NaN_4
# Define replacement values
replacement_value_1 = (-11.742500000000291, -11.743)
replacement_value_2 = (-15.436499999999796, -15.436)
replacement_value_3 = (44.376500000002125, 44.377)
replacement_value_4 = (57.71050000000105, 57.711)
replacement_value_5 = (3.494999999999891, 3.495)

# Replace values in specific columns
dfIntel_without_NaN_4['Capital Expenditure'] = dfIntel_without_NaN_4['Capital Expenditure'].replace(*replacement_value_1)
dfIntel_without_NaN_4['Net Common Stock Issuance'] = dfIntel_without_NaN_4['Net Common Stock Issuance'].replace(*replacement_value_2)
dfIntel_without_NaN_4['Operating Cash Flow'] = dfIntel_without_NaN_4['Operating Cash Flow'].replace(*replacement_value_3)
dfIntel_without_NaN_4['EBITDA'] = dfIntel_without_NaN_4['EBITDA'].replace(*replacement_value_4)
dfIntel_without_NaN_4['Net Issuance Payments Of Debt']=dfIntel_without_NaN_4['Net Issuance Payments Of Debt'].replace(*replacement_value_5)
dfIntel_without_NaN_4
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  Repayment Of Debt  \
# 2024-12-31                                       -15.656             -9.637
# 2023-12-31                                       -14.279             -4.367
# 2022-12-31                                        -9.411             -4.984
# 2021-12-31                                         9.127             -2.500
#
# Scaled Cash Flow Statement (in billions)  Issuance Of Debt  \
# 2024-12-31                                          10.324
# 2023-12-31                                          11.391
# 2022-12-31                                          10.493
# 2021-12-31                                           4.974
#
# Scaled Cash Flow Statement (in billions)  Issuance Of Capital Stock  \
# 2024-12-31                                                   12.714
# 2023-12-31                                                    1.511
# 2022-12-31                                                    1.032
# ...

# %%
dfIntel_without_NaN_4[cols_for_analysis].plot(kind='line', figsize=(10,6))
plt.title('Trend Analysis Intel (in billions)')
plt.xlabel('Year')
plt.ylabel('Cash Flow (billions)')
plt.legend()
plt.grid(True)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the x-axis positions for each label
x = np.arange(len(cols_for_analysis))

# Define the width of each bar
bar_width = 0.25

# Plotting the bars for each company for financial metrics
plt.figure(figsize=(12, 8))

# NVIDIA bars for financial metrics
plt.bar(x - bar_width, df_without_NaN[cols_for_analysis].mean(), width=bar_width, label='NVIDIA')

# AMD bars for financial metrics
plt.bar(x, dfAMD_without_NaN_3[cols_for_analysis].mean(), width=bar_width, label='AMD')

# Intel bars for financial metrics
plt.bar(x + bar_width, dfIntel_without_NaN_4[cols_for_analysis].mean(), width=bar_width, label='Intel')

# Setting labels and title for financial metrics plot
plt.xlabel('Metrics')
plt.ylabel('Mean Values (in billions)')
plt.title('Comparison of Mean Financial Metrics Across Companies (2020-2024)')
plt.xticks(x, cols_for_analysis, rotation=45)
plt.legend()

plt.show()

# %%
dfIntel_without_NaN_4.loc['2024-12-31','Market Cap']=180.28
dfAMD_without_NaN_3.loc['2024-12-31','Market Cap']=308.10

# %%
# Plotting market capitalization for each company
plt.figure(figsize=(8, 6))

plt.bar(['NVIDIA', 'AMD', 'Intel'], 
        [df_without_NaN['Market Cap'].mean(), 
         dfAMD_without_NaN_3['Market Cap'].mean(), 
         dfIntel_without_NaN_4['Market Cap'].mean()], 
        color=['blue', 'green', 'orange'])

# Setting labels and title for market capitalization plot
plt.xlabel('Company')
plt.ylabel('Mean Market Capitalization')
plt.title('Comparison of Mean Market Capitalization Across Companies (2020-2024)')

plt.show()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression


df_without_NaN['Year'] = [2022, 2023, 2024, 2025]

models_and_predictions_NVIDIA = {}

for column in cols_for_analysis:
    X_NVIDIA = df_without_NaN[X_columns] 
    y_NVIDIA = df_without_NaN[column]    
    
    model_NVIDIA = LinearRegression()
    model_NVIDIA.fit(X_NVIDIA, y_NVIDIA)
    
    
    predicted_values_2024_NVIDIA = model_NVIDIA.predict(pd.DataFrame({'Year': [2024]}))
    
    models_and_predictions_NVIDIA[column] = {
        'model': model_NVIDIA, 
        'predicted_values_2024': predicted_values_2024_NVIDIA
    }

for column, data in models_and_predictions_NVIDIA.items():
    print(f"Predicted {column} for NVIDIA in 2024:", data['predicted_values_2024'][0])
# Out:
# Predicted Operating Cash Flow for NVIDIA in 2024: 17.362400000005437
# Predicted Capital Expenditure for NVIDIA in 2024: -1.4776999999999134
# Predicted Net Common Stock Issuance for NVIDIA in 2024: -8.288899999999558
# Predicted Net Issuance Payments Of Debt for NVIDIA in 2024: 1.2158000000003995
# Predicted EBITDA for NVIDIA in 2024: 18.782899999998335

# %%
df_without_NaN_2 = df_without_NaN.copy()
df_without_NaN_2 = dfAMD_without_NaN_3.fillna(0)

# Define replacement values
replacement_value_1 = (-0.17150000000000887, -0.1715)
replacement_value_2 = (-0.3714999999999691, -0.3715)
replacement_value_3 = (1.9979999999999905, 1.998)
replacement_value_4 = (0.8079999999999927, 0.808)
replacement_value_5 = (0,0)

# Replace values in specific columns
df_without_NaN_2['Capital Expenditure'] = df_without_NaN_2['Capital Expenditure'].replace(*replacement_value_1)
df_without_NaN_2['Net Common Stock Issuance'] = df_without_NaN_2['Net Common Stock Issuance'].replace(*replacement_value_2)
df_without_NaN_2['Operating Cash Flow'] = df_without_NaN_2['Operating Cash Flow'].replace(*replacement_value_3)
df_without_NaN_2['EBITDA'] = df_without_NaN_2['EBITDA'].replace(*replacement_value_4)
df_without_NaN_2['Net Issuance Payments Of Debt']=df_without_NaN_2['Net Issuance Payments Of Debt'].replace(*replacement_value_5)
df_without_NaN_2
# Out:
# Scaled Cash Flow Statement (in billions)  Free Cash Flow  \
# 2024-12-31                                         2.405
# 2023-12-31                                         1.121
# 2022-12-31                                         3.115
# 2021-12-31                                         3.220
#
# Scaled Cash Flow Statement (in billions)  Repurchase Of Capital Stock  \
# 2024-12-31                                                     -1.590
# 2023-12-31                                                     -1.412
# 2022-12-31                                                     -4.108
# 2021-12-31                                                     -1.999
#
# Scaled Cash Flow Statement (in billions)  Repayment Of Debt  Issuance Of Debt  \
# 2024-12-31                                           -0.750             0.000
# 2023-12-31                                            0.000             0.000
# 2022-12-31                                           -0.312             0.991
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the x-axis positions for each label
x = np.arange(len(cols_for_analysis))

# Define the width of each bar
bar_width = 0.25

# Plotting the bars for each company for financial metrics
plt.figure(figsize=(12, 8))

# NVIDIA bars for financial metrics
plt.bar(x - bar_width, df_without_NaN[cols_for_analysis].mean(), width=bar_width, label='NVIDIA')

# AMD bars for financial metrics
plt.bar(x, dfAMD_without_NaN_3[cols_for_analysis].mean(), width=bar_width, label='AMD')

# Intel bars for financial metrics
plt.bar(x + bar_width, dfIntel_without_NaN_4[cols_for_analysis].mean(), width=bar_width, label='Intel')

# Setting labels and title for financial metrics plot
plt.xlabel('Metrics')
plt.ylabel('Mean Values (in billions)')
plt.title('Comparison of Mean Financial Metrics Across Companies (2020-2024)')
plt.xticks(x, cols_for_analysis, rotation=45)
plt.legend()

plt.show()

# %%
def get_nvda_stock_data():
    start_date = "2019-05-01"
    end_date = "2024-04-12"
    nvdadata = yf.download(ticker_symbol, start = start_date, end = end_date, auto_adjust=False)
    return nvdadata
nvda_stock_data = get_nvda_stock_data()
print(nvda_stock_data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price      Adj Close    Close     High      Low     Open     Volume
# Ticker          NVDA     NVDA     NVDA     NVDA     NVDA       NVDA
# Date
# 2019-05-01  4.479326  4.51175  4.62025  4.51150  4.57775  354280000
# 2019-05-02  4.546836  4.57975  4.62175  4.47800  4.52150  394684000
# 2019-05-03  4.542369  4.57525  4.59825  4.51325  4.58825  336824000
# 2019-05-06  4.463937  4.49625  4.50850  4.35000  4.38750  422176000
# 2019-05-07  4.296649  4.32775  4.44750  4.27925  4.44750  555220000

# %%
nvda_stock_data_df = pd.DataFrame(nvda_stock_data)
nvda_stock_data_df
# Out:
# Price       Adj Close      Close       High        Low       Open     Volume
# Ticker           NVDA       NVDA       NVDA       NVDA       NVDA       NVDA
# Date
# 2019-05-01   4.479326   4.511750   4.620250   4.511500   4.577750  354280000
# 2019-05-02   4.546836   4.579750   4.621750   4.478000   4.521500  394684000
# ...               ...        ...        ...        ...        ...        ...
# 2024-04-10  87.004364  87.039001  87.400002  83.709000  83.926003  431929000
# 2024-04-11  90.579941  90.615997  90.738998  86.926003  87.419998  431637000
#
# [1246 rows x 6 columns]

# %%
def get_amd_stock_data():
    start_date = "2019-05-01"
    end_date = "2024-04-12"
    amddata = yf.download("AMD", start = start_date, end = end_date, auto_adjust=False)
    return amddata
amd_stock_data = get_amd_stock_data()
amd_stock_data_df = pd.DataFrame(amd_stock_data)
amd_stock_data_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Ticker             AMD         AMD         AMD         AMD         AMD
# Date
# 2019-05-01   26.809999   26.809999   29.150000   26.780001   28.950001
# 2019-05-02   28.290001   28.290001   28.639999   26.610001   26.940001
# ...                ...         ...         ...         ...         ...
# 2024-04-10  167.139999  167.139999  169.779999  164.000000  166.710007
# 2024-04-11  170.500000  170.500000  170.949997  166.550003  167.550003
#
# Price          Volume
# Ticker            AMD
# Date
# 2019-05-01  136066900
# 2019-05-02  100514800
# ...               ...
# 2024-04-10   59600000
# 2024-04-11   48994500
#
# [1246 rows x 6 columns]

# %%
def get_intel_stock_data():
    start_date = "2019-05-01"
    end_date = "2024-04-12"
    inteldata = yf.download("INTC", start = start_date, end = end_date, auto_adjust=False)
    return inteldata
intel_stock_data = get_intel_stock_data()
intel_stock_data_df = pd.DataFrame(intel_stock_data)
intel_stock_data_df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price       Adj Close      Close       High        Low       Open    Volume
# Ticker           INTC       INTC       INTC       INTC       INTC      INTC
# Date
# 2019-05-01  43.962036  50.759998  51.599998  50.740002  51.099998  20467600
# 2019-05-02  43.780155  50.549999  51.330002  50.119999  50.799999  22655400
# ...               ...        ...        ...        ...        ...       ...
# 2024-04-10  36.815971  37.200001  38.220001  37.020000  38.020000  51108400
# 2024-04-11  37.241531  37.630001  37.669998  37.080002  37.430000  41909100
#
# [1246 rows x 6 columns]

# %%
nvda_close = nvda_stock_data['Close']
nvda_stock_data = nvda_stock_data.loc['2019-05-01':'2024-04-11']
nvda_stock_data['Returns'] = nvda_stock_data['Close'].pct_change() 
average_return = nvda_stock_data['Returns'].mean() 
stdev = nvda_stock_data['Returns'].std() 
print("Average Return:", average_return)
print("Standard Deviation:", stdev)
# Out:
# Average Return: 0.00294274764231304
# Standard Deviation: 0.03274164953718264
